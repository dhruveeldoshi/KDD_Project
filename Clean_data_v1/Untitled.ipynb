# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
url = "C:\\Users\\sach2\\Desktop\\Masters\\Semester 2\\CS 513 Data mining\\Project\\Clean Data\\Clean_data_v1\\Fatal_shooting_clean_v1.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#         id        date   manner_of_death       armed  age gender race  \
# 0        3  2015-01-02              shot         gun   53      M    A
# 1        4  2015-01-02              shot         gun   47      M    W
# 2        5  2015-01-03  shot and Tasered     unarmed   23      M    H
# 3        8  2015-01-04              shot  toy weapon   32      M    W
# 4        9  2015-01-04              shot    nail gun   39      M    H
# ...    ...         ...               ...         ...  ...    ...  ...
# 5635  6769  2021-04-10              shot         gun   48      M    O
# 5636  6771  2021-04-10              shot  metal pipe   27      M    O
# 5637  6775  2021-04-10              shot       knife   37      M    O
# 5638  6768  2021-04-12              shot         gun   28      M    B
# 5639  6778  2021-04-13              shot       knife   16      M    W
#
#                city state  signs_of_mental_illness threat_level  flee  \
# ...

# %%
# Out:
#        manner_of_death       armed  age gender race           city state  \
# 0                 shot         gun   53      M    A        Shelton    WA
# 1                 shot         gun   47      M    W          Aloha    OR
# 2     shot and Tasered     unarmed   23      M    H        Wichita    KS
# 3                 shot  toy weapon   32      M    W  San Francisco    CA
# 4                 shot    nail gun   39      M    H          Evans    CO
# ...                ...         ...  ...    ...  ...            ...   ...
# 5635              shot         gun   48      M    O   San Fernando    CA
# 5636              shot  metal pipe   27      M    O       Rockford    IL
# 5637              shot       knife   37      M    O     San Marcos    TX
# 5638              shot         gun   28      M    B         Bremen    GA
# 5639              shot       knife   16      M    W    Leonardtown    MD
#
#       signs_of_mental_illness threat_level  flee  body_camera
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ccece3703028> in <module>
# ----> 1 ax = sns.heatmap(df.iloc[:,2:])
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
# ...
