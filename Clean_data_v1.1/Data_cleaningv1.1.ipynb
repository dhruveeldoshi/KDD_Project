# %%
import pandas as pd
import numpy as np

# %%
url = "C:\\Users\\sach2\\Desktop\\Masters\\Semester 2\\CS 513 Data mining\\Project\\demo\\CS513_Project (1)\\fatal-police-shootings-data.csv"
df = pd.read_csv(url,skipinitialspace=True)

# %%
df
df.isna().sum()
# Out:
# id                           0
# name                       229
# date                         0
# manner_of_death              0
# armed                      208
# age                        275
# gender                       1
# race                       543
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       374
# body_camera                  0
# longitude                  301
# latitude                   301
# is_geocoding_exact           0
# dtype: int64

# %%
print(df.replace(r'^\s*$', np.nan, regex=True, inplace=True))
# Out:
# None

# %%
df
# Out:
#         id                    name        date   manner_of_death  \
# 0        3              Tim Elliot  2015-01-02              shot
# 1        4        Lewis Lee Lembke  2015-01-02              shot
# 2        5      John Paul Quintero  2015-01-03  shot and Tasered
# 3        8         Matthew Hoffman  2015-01-04              shot
# 4        9       Michael Rodriguez  2015-01-04              shot
# ...    ...                     ...         ...               ...
# 6209  6767           Daunte Wright  2021-04-11              shot
# 6210  6768  Pier Alexander Shelton  2021-04-12              shot
# 6211  6778              Peyton Ham  2021-04-13              shot
# 6212  6779              Jacob Wood  2021-04-14              shot
# 6213  6780          Marcelo Garcia  2021-04-14  shot and Tasered
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          Shelton    WA
# ...

# %%
df.armed.isna().sum()
# Out:
# 208

# %%
df.isna().sum()
# Out:
# id                           0
# name                       229
# date                         0
# manner_of_death              0
# armed                      208
# age                        275
# gender                       1
# race                       543
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       374
# body_camera                  0
# longitude                  301
# latitude                   301
# is_geocoding_exact           0
# dtype: int64

# %%
df=df.dropna(subset=['armed'])

# %%
df.isna().sum()
# Out:
# id                           0
# name                       225
# date                         0
# manner_of_death              0
# armed                        0
# age                        270
# gender                       1
# race                       534
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       366
# body_camera                  0
# longitude                  291
# latitude                   291
# is_geocoding_exact           0
# dtype: int64

# %%
df.armed.isna().sum()
# df.flee.isnull().sum()
df=df.dropna(subset=['flee'])
df.isna().sum()
# Out:
# id                           0
# name                       198
# date                         0
# manner_of_death              0
# armed                        0
# age                        240
# gender                       1
# race                       481
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                         0
# body_camera                  0
# longitude                  277
# latitude                   277
# is_geocoding_exact           0
# dtype: int64

# %%
df.flee.unique()
# Out:
# array(['Not fleeing', 'Car', 'Foot', 'Other'], dtype=object)

# %%
# Replacing string values with integer
# Not fleeing:0
# car:1
# other:1
# foot:1
df.flee=df.flee.map({'Not fleeing':0,'Car':1,'Foot':1,'Other':1})

# %%
# in age column assigning mean of the column
df['age'].fillna(value=df['age'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# id                           0
# name                       198
# date                         0
# manner_of_death              0
# armed                        0
# age                          0
# gender                       1
# race                       481
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                         0
# body_camera                  0
# longitude                  277
# latitude                   277
# is_geocoding_exact           0
# dtype: int64

# %%
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#    flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
df.age=df.age.astype(int)

# %%
# assigning 'O' to a na in gender column
df['race'].fillna(value='O', inplace=True)
df
# Out:
#         id                    name        date   manner_of_death       armed  \
# 0        3              Tim Elliot  2015-01-02              shot         gun
# 1        4        Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5      John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8         Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9       Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                     ...         ...               ...         ...
# 6205  6769                     NaN  2021-04-10              shot         gun
# 6207  6771                     NaN  2021-04-10              shot  metal pipe
# 6208  6775                     NaN  2021-04-10              shot       knife
# 6210  6768  Pier Alexander Shelton  2021-04-12              shot         gun
# 6211  6778              Peyton Ham  2021-04-13              shot       knife
#
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# name                       198
# date                         0
# manner_of_death              0
# armed                        0
# age                          0
# gender                       1
# race                         0
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                         0
# body_camera                  0
# longitude                  277
# latitude                   277
# is_geocoding_exact           0
# dtype: int64

# %%
# assigning a M to na in a gender column (Only single value was missing)
df['gender'].fillna(value='M', inplace=True)
df
# Out:
#         id                    name        date   manner_of_death       armed  \
# 0        3              Tim Elliot  2015-01-02              shot         gun
# 1        4        Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5      John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8         Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9       Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                     ...         ...               ...         ...
# 6205  6769                     NaN  2021-04-10              shot         gun
# 6207  6771                     NaN  2021-04-10              shot  metal pipe
# 6208  6775                     NaN  2021-04-10              shot       knife
# 6210  6768  Pier Alexander Shelton  2021-04-12              shot         gun
# 6211  6778              Peyton Ham  2021-04-13              shot       knife
#
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# name                       198
# date                         0
# manner_of_death              0
# armed                        0
# age                          0
# gender                       0
# race                         0
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                         0
# body_camera                  0
# longitude                  277
# latitude                   277
# is_geocoding_exact           0
# dtype: int64

# %%
# Deleting unwanted coulumns

# %%
del df['latitude']

# %%
del df['longitude']

# %%
del df['name']

# %%
del df['is_geocoding_exact']

# %%
df
# Out:
#         id        date   manner_of_death       armed  age gender race  \
# 0        3  2015-01-02              shot         gun   53      M    A
# 1        4  2015-01-02              shot         gun   47      M    W
# 2        5  2015-01-03  shot and Tasered     unarmed   23      M    H
# 3        8  2015-01-04              shot  toy weapon   32      M    W
# 4        9  2015-01-04              shot    nail gun   39      M    H
# ...    ...         ...               ...         ...  ...    ...  ...
# 6205  6769  2021-04-10              shot         gun   48      M    O
# 6207  6771  2021-04-10              shot  metal pipe   27      M    O
# 6208  6775  2021-04-10              shot       knife   37      M    O
# 6210  6768  2021-04-12              shot         gun   28      M    B
# 6211  6778  2021-04-13              shot       knife   16      M    W
#
#                city state  signs_of_mental_illness threat_level  flee  \
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# dtype: int64

# %%
df_clean=df
df_clean.head()
df_clean.isnull().sum()
# Out:
# id                         0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# dtype: int64

# %%
df_clean.threat_level.unique()
# Out:
# array(['attack', 'other', 'undetermined'], dtype=object)

# %%
# convert threat_level column 
# attack:1
# other:2
# undetermined:0

df_clean
# Out:
#         id        date   manner_of_death       armed  age gender race  \
# 0        3  2015-01-02              shot         gun   53      M    A
# 1        4  2015-01-02              shot         gun   47      M    W
# 2        5  2015-01-03  shot and Tasered     unarmed   23      M    H
# 3        8  2015-01-04              shot  toy weapon   32      M    W
# 4        9  2015-01-04              shot    nail gun   39      M    H
# ...    ...         ...               ...         ...  ...    ...  ...
# 6205  6769  2021-04-10              shot         gun   48      M    O
# 6207  6771  2021-04-10              shot  metal pipe   27      M    O
# 6208  6775  2021-04-10              shot       knife   37      M    O
# 6210  6768  2021-04-12              shot         gun   28      M    B
# 6211  6778  2021-04-13              shot       knife   16      M    W
#
#                city state  signs_of_mental_illness threat_level  flee  \
# ...

# %%
df_clean.to_csv(r'C:\\Users\\sach2\\Desktop\\Masters\\Semester 2\\CS 513 Data mining\\Project\\Clean Data\\Clean_data_v1.1\\Fatal_shooting_clean_v1.1.csv',index=False)
